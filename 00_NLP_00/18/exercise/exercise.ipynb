# %%
import pandas as pd

# %%
df = pd.read_csv('Emotion_classify_Data.csv')
df
# Out:
#                                                 Comment Emotion
# 0     i seriously hate one subject to death but now ...    fear
# 1                    im so full of life i feel appalled   anger
# 2     i sit here to write i start to dig out my feel...    fear
# 3     ive been really angry with r and i feel like a...     joy
# 4     i feel suspicious if there is no one outside l...    fear
# ...                                                 ...     ...
# 5932                 i begun to feel distressed for you    fear
# 5933  i left feeling annoyed and angry thinking that...   anger
# 5934  i were to ever get married i d have everything...     joy
# 5935  i feel reluctant in applying there because i w...    fear
# 5936  i just wanted to apologize to you because i fe...   anger
#
# [5937 rows x 2 columns]

# %%
df.Emotion.value_counts()
# Out:
# anger    2000
# joy      2000
# fear     1937
# Name: Emotion, dtype: int64

# %%
df['Emotion_label'] = df.Emotion.map({
    'anger' : 0,
    'joy' : 1,
    'fear' : 2
})

# %%
df
# Out:
#                                                 Comment Emotion  Emotion_label
# 0     i seriously hate one subject to death but now ...    fear              2
# 1                    im so full of life i feel appalled   anger              0
# 2     i sit here to write i start to dig out my feel...    fear              2
# 3     ive been really angry with r and i feel like a...     joy              1
# 4     i feel suspicious if there is no one outside l...    fear              2
# ...                                                 ...     ...            ...
# 5932                 i begun to feel distressed for you    fear              2
# 5933  i left feeling annoyed and angry thinking that...   anger              0
# 5934  i were to ever get married i d have everything...     joy              1
# 5935  i feel reluctant in applying there because i w...    fear              2
# 5936  i just wanted to apologize to you because i fe...   anger              0
#
# [5937 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
v = CountVectorizer(ngram_range=(3,3))
v.fit(df.Comment)
transformed = v.transform(df.Comment)
transformed.toarray()[:1]
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
v.vocabulary_
# Out:
# {'seriously hate one': 55759,
#  'hate one subject': 28713,
#  'one subject to': 48830,
#  'subject to death': 59887,
#  'to death but': 68397,
#  'death but now': 15715,
#  'but now feel': 11870,
#  'now feel reluctant': 46286,
#  'feel reluctant to': 21587,
#  'reluctant to drop': 53924,
#  'to drop it': 68489,
#  'im so full': 32599,
#  'so full of': 57401,
#  'full of life': 26176,
#  'of life feel': 47017,
#  'life feel appalled': 38486,
#  'sit here to': 56782,
#  'here to write': 30382,
#  'to write start': 70315,
#  'write start to': 78200,
#  'start to dig': 58987,
#  'to dig out': 68421,
#  'dig out my': 16397,
#  'out my feelings': 49931,
#  'my feelings and': 43670,
#  'feelings and think': 23927,
#  'and think that': 5413,
#  'think that am': 66391,
#  'that am afraid': 61178,
#  'am afraid to': 2214,
#  'afraid to accept': 1089,
#  'to accept the': 67889,
#  'accept the possibility': 674,
#  'the possibility that': 64270,
#  'possibility that he': 51817,
#  'that he might': 61641,
#  'he might not': 29663,
#  'might not make': 42134,
#  'not make it': 45926,
#  'ive been really': 36310,
#  'been really angry': 9733,
#  'really angry with': 53303,
#  'angry with and': 5905,
#  'with and feel': 76751,
#  'and feel like': 3731,
#  'feel like an': 20964,
#  'like an idiot': 38646,
#  'an idiot for': 2994,
#  'idiot for trusting': 31766,
#  'for trusting him': 25312,
#  'trusting him in': 71075,
#  'him in the': 30599,
#  'in the first': 33553,
#  'the first place': 63389,
#  'feel suspicious if': 21972,
#  'suspicious if there': 60316,
#  'if there is': 31988,
#  'there is no': 65568,
#  'is no one': 34951,
#  'no one outside': 45483,
#  'one outside like': 48817,
#  'outside like the': 50088,
#  'like the rapture': 39226,
#  'the rapture has': 64345,
#  'rapture has happened': 52940,
#  'has happened or': 28608,
#  'happened or something': 28375,
#  'feel jealous becasue': 20902,
#  'jealous becasue wanted': 36460,
#  'becasue wanted that': 9133,
#  'wanted that kind': 73268,
#  'that kind of': 61842,
#  'kind of love': 37322,
#  'of love the': 47036,
#  'love the true': 40356,
#  'the true connection': 64833,
#  'true connection between': 71012,
#  'connection between two': 14408,
#  'between two souls': 10385,
#  'two souls and': 71324,
#  'souls and wanted': 58611,
#  'and wanted that': 5589,
#  'when friend of': 75382,
#  'friend of mine': 25674,
#  'of mine keeps': 47078,
#  'mine keeps telling': 42220,
#  'keeps telling me': 37187,
#  'telling me morbid': 60809,
#  'me morbid things': 41555,
#  'morbid things that': 42495,
#  'things that happened': 66208,
#  'that happened to': 61580,
#  'happened to his': 28380,
#  'to his dog': 69033,
#  'finally fell asleep': 24374,
#  'fell asleep feeling': 24106,
#  'asleep feeling angry': 7554,
#  'feeling angry useless': 22589,
#  'angry useless and': 5902,
#  'useless and still': 72271,
#  'and still full': 5147,
#  'still full of': 59281,
#  'full of anxiety': 26171,
#  'feel bit annoyed': 20216,
#  'bit annoyed and': 10480,
#  'annoyed and antsy': 5936,
#  'and antsy in': 3191,
#  'antsy in good': 6058,
#  'in good way': 33056,
#  'feel like ve': 21132,
#  'like ve regained': 39334,
#  've regained another': 72433,
#  'regained another vital': 53756,
#  'another vital part': 6024,
#  'vital part of': 72905,
#  'part of my': 50551,
#  'of my life': 47141,
#  'my life which': 43989,
#  'life which is': 38555,
#  'which is living': 75874,
#  'feel bit like': 20232,
#  'bit like franz': 10538,
#  'like franz liebkind': 38775,
#  'franz liebkind in': 25574,
#  'liebkind in the': 38429,
#  'in the producers': 33616,
#  'the producers not': 64299,
#  'producers not many': 52360,
#  'not many people': 45931,
#  'many people know': 40956,
#  'people know it': 50900,
#  'know it but': 37527,
#  'it but the': 35435,
#  'but the fuhrer': 11991,
#  'the fuhrer was': 63438,
#  'fuhrer was terrific': 26155,
#  'was terrific dancer': 73930,
#  'was feeling at': 73525,
#  'feeling at the': 22631,
#  'at the start': 7921,
#  'the start didnt': 64620,
#  'start didnt want': 58961,
#  'didnt want to': 16329,
#  'want to move': 73214,
#  'to move much': 69351,
#  'move much at': 43012,
#  'much at all': 43099,
#  'at all was': 7647,
#  'all was really': 1765,
#  'was really glad': 73822,
#  'really glad to': 53401,
#  'glad to experience': 26940,
#  'to experience this': 68547,
#  'experience this glimpse': 19346,
#  'this glimpse into': 66684,
#  'glimpse into the': 26980,
#  'into the sort': 34460,
#  'the sort of': 64597,
#  'sort of vibrant': 58596,
#  'of vibrant energy': 47847,
#  'vibrant energy will': 72746,
#  'energy will gain': 18335,
#  'will gain through': 76499,
#  'gain through out': 26278,
#  'through out the': 67438,
#  'out the year': 50003,
#  'was bitten by': 73445,
#  'bitten by dog': 10689,
#  'do not always': 16890,
#  'not always find': 45609,
#  'always find myself': 2145,
#  'find myself feeling': 24427,
#  'myself feeling thankful': 44638,
#  'feeling thankful but': 23677,
#  'thankful but over': 61116,
#  'but over the': 11892,
#  'over the years': 50186,
#  'the years ve': 65085,
#  'years ve gathered': 78475,
#  've gathered few': 72425,
#  'gathered few tricks': 26330,
#  'few tricks that': 24292,
#  'tricks that allow': 70958,
#  'that allow me': 61171,
#  'allow me to': 1791,
#  'me to feel': 41698,
#  'to feel grateful': 68629,
#  'feel grateful in': 20612,
#  'grateful in the': 27634,
#  'in the face': 33546,
#  'the face of': 63294,
#  'face of moments': 19559,
#  'of moments when': 47084,
#  'moments when the': 42399,
#  'when the last': 75602,
#  'the last thing': 63720,
#  'last thing want': 37861,
#  'thing want to': 66094,
#  'want to do': 73191,
#  'to do is': 68449,
#  'do is say': 16846,
#  'is say thanks': 35071,
#  'just try not': 37057,
#  'try not to': 71112,
#  'not to talk': 46095,
#  'to talk to': 69953,
#  'talk to anyone': 60609,
#  'to anyone when': 67970,
#  'anyone when feel': 6274,
#  'when feel irritable': 75343,
#  'feel irritable like': 20823,
#  'irritable like that': 34605,
#  'feel like they': 21117,
#  'like they hated': 39255,
#  'they hated me': 65908,
#  'hated me since': 28760,
#  'me since then': 41611,
#  'dont know who': 17398,
#  'know who wrote': 37671,
#  'who wrote the': 76224,
#  'wrote the following': 78356,
#  'the following little': 63409,
#  'following little note': 24758,
#  'little note but': 39674,
#  'note but this': 46146,
#  'but this is': 12033,
#  'this is how': 66728,
#  'is how feel': 34851,
#  'how feel today': 31291,
#  'feel today if': 22241,
#  'today if offended': 70380,
#  'if offended by': 31928,
#  'offended by the': 48049,
#  'by the following': 12353,
#  'the following posting': 63412,
#  'following posting then': 24761,
#  'posting then you': 51885,
#  'then you obviously': 65488,
#  'you obviously have': 78882,
#  'obviously have not': 46456,
#  'have not lived': 29197,
#  'not lived long': 45921,
#  'lived long enough': 39798,
#  'long enough to': 39937,
#  'enough to be': 18437,
#  'to be compromised': 68032,
#  'be compromised on': 8659,
#  'compromised on how': 14266,
#  'on how you': 48361,
#  'how you act': 31461,
#  'you act or': 78585,
#  'act or believe': 788,
#  'feel offended choose': 21360,
#  'offended choose to': 48052,
#  'choose to tell': 13589,
#  'to tell you': 69966,
#  'tell you guys': 60793,
#  'you guys how': 78795,
#  'guys how feel': 27984,
#  'how feel because': 31282,
#  'feel because treated': 20205,
#  'because treated you': 9456,
#  'treated you guys': 70922,
#  'you guys as': 78791,
#  'guys as friends': 27974,
#  'as friends and': 7102,
#  'friends and would': 25719,
#  'and would want': 5743,
#  'would want to': 78123,
#  'want to put': 73223,
#  'to put stop': 69577,
#  'put stop to': 52642,
#  'stop to all': 59436,
#  'to all these': 67932,
#  'all these nonsense': 1731,
#  'remember feeling as': 53977,
#  'feeling as if': 22619,
#  'as if didn': 7145,
#  'if didn belong': 31810,
#  'didn belong and': 16216,
#  'belong and that': 10218,
#  'and that wasn': 5271,
#  'that wasn smart': 62465,
#  'wasn smart enough': 74050,
#  'smart enough cool': 57084,
#  'enough cool enough': 18406,
#  'cool enough or': 14677,
#  'enough or even': 18419,
#  'or even young': 49213,
#  'even young enough': 18859,
#  'feel like have': 21014,
#  'like have to': 38813,
#  'have to redeem': 29381,
#  'to redeem myself': 69622,
#  'redeem myself even': 53710,
#  'myself even though': 44620,
#  'even though think': 18835,
#  'though think they': 67233,
#  'think they realized': 66416,
#  'they realized why': 65959,
#  'realized why was': 53291,
#  'why was distraught': 76356,
#  'was distraught and': 73489,
#  'distraught and were': 16651,
#  'and were ok': 5647,
#  'were ok with': 74927,
#  'ok with it': 48181,
#  'hope that the': 31036,
#  'that the next': 62273,
#  'the next quote': 64009,
#  'next quote will': 45301,
#  'quote will be': 52852,
#  'will be able': 76404,
#  'be able to': 8561,
#  'able to let': 51,
#  'to let my': 69186,
#  'let my special': 38351,
#  'my special someone': 44386,
#  'special someone knows': 58710,
#  'someone knows what': 58200,
#  'knows what im': 37736,
#  'what im feeling': 75074,
#  'im feeling insecure': 32296,
#  'feeling insecure about': 23014,
#  'insecure about and': 34029,
#  'about and understand': 91,
#  'and understand that': 5514,
#  'understand that no': 71526,
#  'that no matter': 61989,
#  'no matter how': 45458,
#  'matter how much': 41069,
#  'how much trust': 31362,
#  'feel much better': 21289,
#  'much better and': 43102,
#  'better and without': 10320,
#  'and without the': 5711,
#  'without the help': 77428,
#  'the help of': 63572,
#  'help of ice': 30028,
#  'am sitting here': 2652,
#  'sitting here typing': 56810,
#  'here typing this': 30386,
#  'typing this and': 71360,
#  'this and wondering': 66525,
#  'and wondering where': 5724,
#  'wondering where belong': 77579,
#  'where belong feeling': 75729,
#  'belong feeling distracted': 10219,
#  'feeling distracted feeling': 22800,
#  'distracted feeling comfortable': 16622,
#  'feeling comfortable feeling': 22737,
#  'comfortable feeling misunderstood': 14085,
#  'feeling misunderstood and': 23185,
#  'misunderstood and hurt': 42310,
#  'still feel its': 59231,
#  'feel its little': 20889,
#  'its little shaky': 36178,
#  'little shaky at': 39712,
#  'shaky at times': 55935,
#  'at times and': 7946,
#  'times and can': 67768,
#  'and can move': 3345,
#  'can move into': 12773,
#  'move into the': 43010,
#  'into the slightly': 34459,
#  'the slightly odd': 64574,
#  'slightly odd jades': 57003,
#  'odd jades hair': 46488,
#  'jades hair in': 36435,
#  'hair in particular': 28267,
#  'in particular seems': 33333,
#  'particular seems prone': 50576,
#  'seems prone to': 55528,
#  'prone to this': 52442,
#  'to this but': 70139,
#  'this but generally': 66583,
#  'but generally it': 11662,
#  'generally it works': 26385,
#  'it works well': 36064,
#  'works well with': 77801,
#  'well with spencers': 74811,
#  'with spencers writing': 77150,
#  'stropped about for': 59722,
#  'about for bit': 174,
#  'for bit feeling': 24860,
#  'bit feeling grumpy': 10516,
#  'feeling grumpy because': 22929,
#  'grumpy because was': 27829,
#  'because was missing': 9468,
#  'was missing out': 73735,
#  'have feeling shall': 29003,
#  'feeling shall go': 23523,
#  'shall go mad': 55946,
#  'am happpy when': 2463,
#  'happpy when get': 28414,
#  'when get good': 75388,
#  'get good results': 26497,
#  'good results in': 27412,
#  'results in the': 54308,
#  'in the field': 33551,
#  'the field of': 63357,
#  'field of academics': 24311,
#  'of academics or': 46495,
#  'academics or athletics': 664,
#  'got the feeling': 27528,
#  'the feeling brig': 63326,
#  'feeling brig is': 22712,
#  'brig is sincere': 11264,
#  'is sincere and': 35083,
#  'sincere and has': 56705,
#  'and has very': 3996,
#  'has very strong': 28677,
#  'very strong desire': 72680,
#  'strong desire to': 59681,
#  'desire to help': 16009,
#  'to help others': 69004,
#  'help others become': 30029,
#  'others become successful': 49699,
#  'become successful both': 9528,
#  'successful both financially': 59918,
#  'both financially and': 11031,
#  'financially and also': 24398,
#  'and also through': 3124,
#  'also through building': 2058,
#  'through building strengthening': 67409,
#  'building strengthening relationships': 11368,
#  'strengthening relationships through': 59594,
#  'relationships through christianity': 53829,
#  'im feeling deeply': 32264,
#  'feeling deeply overwhelmed': 22782,
#  'deeply overwhelmed by': 15824,
#  'overwhelmed by these': 50247,
#  'by these ordinary': 12420,
#  'these ordinary tasks': 65742,
#  'feel so grouchy': 21792,
#  'so grouchy and': 57422,
#  'grouchy and irritable': 27765,
#  'and irritable when': 4228,
#  'irritable when im': 34616,
#  'when im sick': 75445,
#  'feel my heart': 21303,
#  'my heart shaky': 43839,
#  'heart shaky all': 29895,
#  'shaky all the': 55917,
#  'all the time': 1719,
#  'the time now': 64769,
#  'expect and feel': 19299,
#  'and feel content': 3699,
#  'feel content with': 20361,
#  'content with that': 14533,
#  'feel amused at': 20065,
#  'amused at the': 2873,
#  'at the absurdity': 7865,
#  'the absurdity of': 62662,
#  'absurdity of it': 660,
#  'of it all': 46974,
#  'end up getting': 18245,
#  'up getting unwanted': 71894,
#  'getting unwanted attention': 26761,
#  'unwanted attention from': 71750,
#  'attention from boys': 8039,
#  'from boys want': 25815,
#  'boys want little': 11161,
#  'want little to': 73145,
#  'little to do': 39749,
#  'to do with': 68472,
#  'do with or': 17004,
#  'with or ill': 77069,
#  'or ill be': 49283,
#  'ill be sort': 32086,
#  'be sort of': 8960,
#  'sort of starting': 58590,
#  'of starting something': 47423,
#  'starting something with': 59046,
#  'something with boy': 58389,
#  'with boy then': 76774,
#  'boy then find': 11137,
#  'then find myself': 65425,
#  'find myself flirtiing': 24428,
#  'myself flirtiing with': 44640,
#  'flirtiing with others': 24683,
#  'with others in': 77075,
#  'others in his': 49709,
#  'in his presence': 33092,
#  'his presence or': 30767,
#  'presence or ill': 52033,
#  'or ill feel': 49284,
#  'ill feel really': 32100,
#  'feel really insincere': 21536,
#  'really insincere around': 53438,
#  'insincere around boys': 34103,
#  'around boys that': 6833,
#  'boys that do': 11160,
#  'that do like': 61400,
#  'just couldnt help': 36742,
#  'couldnt help feeling': 14918,
#  'help feeling little': 30002,
#  'feeling little bit': 23135,
#  'little bit bitter': 39541,
#  'bit bitter towards': 10496,
#  'bitter towards his': 10719,
#  'towards his great': 70802,
#  'his great big': 30722,
#  'great big happy': 27656,
#  'big happy grin': 10417,
#  'go back to': 27012,
#  'back to my': 8367,
#  'to my point': 69397,
#  'my point about': 44248,
#  'point about what': 51653,
#  'about what an': 582,
#  'what an easy': 74997,
#  'an easy sell': 2945,
#  'easy sell getting': 17922,
#  'sell getting folk': 55648,
#  'getting folk to': 26713,
#  'folk to feel': 24737,
#  'to feel really': 68679,
#  'feel really virtuous': 21558,
#  'really virtuous for': 53543,
#  'virtuous for not': 72871,
#  'for not doing': 25106,
#  'not doing what': 45721,
#  'doing what they': 17183,
#  'what they dont': 75167,
#  'they dont want': 65877,
#  'dont want to': 17457,
#  'to do anyway': 68437,
#  'im feeling bit': 32248,
#  'feeling bit more': 22665,
#  'bit more sociable': 10550,
#  'more sociable now': 42717,
#  'sociable now although': 57894,
#  'now although dont': 46227,
#  'although dont think': 2082,
#  'dont think ill': 17441,
#  'think ill be': 66320,
#  'ill be able': 32081,
#  'able to express': 34,
#  'to express everything': 68553,
#  'express everything want': 19410,
#  'everything want to': 19136,
#  'want to say': 73227,
#  'would feel joyful': 78018,
#  'at certain situation': 7668,
#  'certain situation felt': 13289,
#  'situation felt myself': 56830,
#  'felt myself neglected': 24165,
#  'myself neglected and': 44692,
#  'neglected and undeservedly': 45028,
#  'and undeservedly harmed': 5518,
#  'felt good and': 24131,
#  'good and feel': 27341,
#  'and feel fine': 3711,
#  'feel fine today': 20521,
#  'fine today too': 24499,
#  'looked at what': 40057,
#  'at what had': 7966,
#  'what had happened': 75047,
#  'had happened to': 28096,
#  'happened to us': 28385,
#  'to us in': 70201,
#  'us in two': 72157,
#  'in two generations': 33749,
#  'two generations and': 71302,
#  'generations and looked': 26395,
#  'and looked at': 4432,
#  'at what hadn': 7967,
#  'what hadn happened': 75049,
#  'hadn happened to': 28240,
#  'happened to them': 28384,
#  'to them in': 70119,
#  'them in two': 65273,
#  'in two or': 33751,
#  'two or three': 71314,
#  'or three and': 49488,
#  'three and instead': 67360,
#  'and instead of': 4212,
#  'instead of feeling': 34151,
#  'of feeling outraged': 46801,
#  'feeling outraged by': 23296,
#  'outraged by their': 50074,
#  'by their history': 12411,
#  'their history of': 65121,
#  'history of aggression': 30806,
#  'of aggression felt': 46502,
#  'aggression felt privileged': 1312,
#  'felt privileged by': 24168,
#  'privileged by it': 52272,
#  'im feeling slightly': 32341,
#  'feeling slightly optimistic': 23545,
#  'feel and some': 20082,
#  'and some is': 5095,
#  'some is just': 58000,
#  'is just hateful': 34878,
#  'just hateful of': 36862,
#  'hateful of hollow': 28788,
#  'of hollow yes': 46927,
#  'hollow yes hear': 30866,
#  'yes hear many': 78494,
#  'hear many smiths': 29823,
#  'many smiths these': 40967,
#  'smiths these days': 57128,
#  'im still feeling': 32621,
#  'still feeling indecisive': 59263,
#  'feeling indecisive im': 23006,
#  'indecisive im polling': 33912,
#  'im polling yall': 32547,
#  'sometime back another': 58398,
#  'back another girl': 8289,
#  'another girl who': 5996,
#  'girl who was': 26813,
#  'who was in': 76207,
#  'was in terms': 73665,
#  'in terms with': 33468,
#  'terms with my': 60872,
#  'with my exboyfriend': 76985,
#  'my exboyfriend came': 43607,
#  'exboyfriend came to': 19192,
#  'came to shout': 12584,
#  'to shout at': 69779,
#  'shout at me': 56403,
#  'at me at': 7767,
#  'me at twelve': 41276,
#  'at twelve midnight': 7960,
#  'twelve midnight it': 71275,
#  'midnight it was': 42084,
#  'it was because': 35970,
#  'was because she': 73426,
#  'because she thought': 9392,
#  'she thought was': 56122,
#  'thought was still': 67289,
#  'was still interested': 73902,
#  'still interested in': 59300,
#  'interested in the': 34277,
#  'in the boy': 33507,
#  'id start feeling': 31717,
#  'start feeling resentful': 58968,
#  'feeling resentful that': 23483,
#  'resentful that lived': 54171,
#  'that lived in': 61866,
#  'lived in part': 39795,
#  'in part of': 33331,
#  'part of the': 50553,
#  'of the country': 47518,
#  'the country where': 63040,
#  'country where the': 14959,
#  'where the sun': 75784,
#  'the sun stubbornly': 64684,
#  'sun stubbornly refuses': 60081,
#  'stubbornly refuses to': 59769,
#  'refuses to show': 53750,
#  'to show itself': 69784,
#  'show itself after': 56419,
#  'itself after the': 36268,
#  'after the end': 1169,
#  'the end of': 63239,
#  'end of september': 18235,
#  'just feel so': 36794,
#  'feel so fucked': 21783,
#  'so fucked up': 57399,
#  'fucked up these': 26137,
#  'up these days': 72006,
#  'confess that was': 14319,
#  'that was feeling': 62436,
#  'was feeling nervous': 73566,
#  'feeling nervous as': 23220,
#  'nervous as made': 45075,
#  'as made my': 7207,
#  'made my way': 40566,
#  'my way to': 44508,
#  'way to the': 74300,
#  'to the event': 70016,
#  'the event venue': 63268,
#  'was really worried': 73830,
#  'really worried that': 53556,
#  'worried that would': 77878,
#  'that would feel': 62569,
#  'would feel intimidated': 78017,
#  'feel intimidated by': 20807,
#  'intimidated by monica': 34323,
#  'by monica but': 12261,
#  'monica but when': 42427,
#  'but when we': 12094,
#  'when we met': 75664,
#  'we met that': 74449,
#  'met that morning': 42058,
#  'that morning she': 61924,
#  'morning she was': 42829,
#  'she was incredibly': 56134,
#  'was incredibly welcoming': 73671,
#  'incredibly welcoming and': 33897,
#  'welcoming and made': 74736,
#  'and made me': 4463,
#  'made me feel': 40558,
#  'me feel relaxed': 41378,
#  'feel relaxed straight': 21577,
#  'relaxed straight away': 53859,
#  'was sick with': 73858,
#  'sick with cold': 56532,
#  'with cold amp': 76787,
#  'cold amp not': 13883,
#  'amp not feeling': 2858,
#  'not feeling well': 45815,
#  'feeling well wondering': 23878,
#  'well wondering if': 74812,
#  'wondering if would': 77578,
#  'if would even': 32031,
#  'would even be': 78004,
#  'even be able': 18679,
#  'able to have': 41,
#  'to have the': 68976,
#  'have the patience': 29316,
#  'the patience to': 64174,
#  'patience to go': 50721,
#  'to go to': 68905,
#  'go to whitleys': 27103,
#  'to whitleys month': 70269,
#  'whitleys month photo': 76036,
#  'month photo shoot': 42438,
#  'like have been': 38804,
#  'have been bit': 28865,
#  'been bit obnoxious': 9586,
#  'bit obnoxious in': 10556,
#  'obnoxious in my': 46440,
#  'in my picture': 33255,
#  'my picture posting': 44235,
#  'feel morally outraged': 21229,
#  'morally outraged and': 42492,
#  'outraged and furious': 50069,
#  'and furious more': 3914,
#  'furious more often': 26238,
#  'more often than': 42671,
#  'often than like': 48142,
#  'feel pissed my': 21436,
#  'pissed my friend': 51407,
#  'my friend didnt': 43739,
#  'friend didnt offer': 25657,
#  'didnt offer me': 16306,
#  'offer me soda': 48087,
#  'feel our hearts': 21385,
#  'our hearts are': 49777,
#  'hearts are treading': 29934,
#  'are treading dangerous': 6748,
#  'treading dangerous territory': 70909,
#  'feel frightened by': 20545,
#  'frightened by it': 25778,
#  'by it all': 12231,
#  'know it was': 37536,
#  'it was not': 35997,
#  'was not pleasant': 73765,
#  'not pleasant for': 45978,
#  'pleasant for her': 51578,
#  'for her and': 24960,
#  'her and feel': 30121,
#  'and feel selfish': 3747,
#  'feel selfish saying': 21672,
#  'selfish saying it': 55633,
#  'saying it but': 55114,
#  'it but think': 35436,
#  'but think would': 12029,
#  'think would have': 66435,
#  'would have fallen': 78039,
#  'have fallen apart': 28991,
#  'fallen apart if': 19676,
#  'apart if had': 6349,
#  'if had been': 31856,
#  'had been there': 28043,
#  'feel shafted or': 21677,
#  'shafted or greedy': 55855,
#  'have just had': 29104,
#  'just had such': 36858,
#  'had such crappy': 28174,
#  'such crappy week': 59955,
#  'crappy week that': 15084,
#  'week that am': 74627,
#  'that am still': 61202,
#  'am still feeling': 2691,
#  'still feeling all': 59257,
#  'feeling all agitated': 22551,
#  'all agitated and': 1482,
#  'agitated and like': 1330,
#  'and like the': 4406,
#  'like the day': 39203,
#  'the day wasn': 63109,
#  'day wasn what': 15613,
#  'wasn what wanted': 74054,
#  'feel rebellious because': 21567,
#  'rebellious because don': 53617,
#  'because don particularly': 9185,
#  'don particularly like': 17267,
#  'particularly like watching': 50595,
#  'like watching romcoms': 39367,
#  'watching romcoms but': 74137,
#  'romcoms but get': 54518,
#  'but get the': 11667,
#  'get the feeling': 26614,
#  'the feeling that': 63338,
#  'feeling that may': 23703,
#  'that may be': 61895,
#  'may be pretty': 41097,
#  'be pretty good': 8872,
#  'pretty good at': 52164,
#  'good at writing': 27355,
#  'at writing them': 7978,
#  'reluctant to just': 53929,
#  'to just leave': 69116,
#  'just leave her': 36896,
#  'leave her alone': 38083,
#  'her alone like': 30115,
#  'alone like that': 1862,
#  'like that without': 39191,
#  'that without helping': 62557,
#  'without helping her': 77402,
#  'helping her enough': 30046,
#  'her enough to': 30171,
#  'enough to repay': 18454,
#  'to repay her': 69651,
#  'repay her goodness': 54070,
#  'her goodness to': 30202,
#  'goodness to me': 27441,
#  'am ashamed when': 2238,
#  'ashamed when feel': 7481,
#  'when feel like': 75345,
#  'feel like that': 21110,
#  'like that the': 39187,
#  'that the moment': 62270,
#  'the moment see': 63885,
#  'moment see terrified': 42381,
#  'see terrified crying': 55426,
#  'terrified crying children': 60913,
#  'crying children and': 15256,
#  'children and dead': 13536,
#  'and dead ones': 3462,
#  'wake up in': 73026,
#  'up in the': 71910,
#  'in the morning': 33588,
#  'the morning and': 63913,
#  'morning and have': 42813,
#  'and have my': 4018,
#  'have my voice': 29169,
#  'my voice and': 44495,
#  'voice and my': 72916,
#  'and my throat': 4613,
#  'my throat feels': 44451,
#  'throat feels ok': 67400,
#  'feels ok but': 24049,
#  'ok but by': 48169,
#  'but by the': 11506,
#  'by the afternoon': 12326,
#  'the afternoon its': 62679,
#  'afternoon its all': 1194,
#  'its all scratchy': 36101,
#  'all scratchy again': 1654,
#  'scratchy again and': 55272,
#  'again and sound': 1213,
#  'and sound like': 5120,
#  'sound like marge': 58619,
#  'like marge simpson': 38998,
#  'marge simpson until': 40990,
#  'simpson until the': 56640,
#  'until the night': 71738,
#  'the night when': 64027,
#  'night when its': 45384,
#  'when its so': 75477,
#  'its so bad': 36228,
#  'so bad and': 57218,
#  'bad and my': 8414,
#  'my throat is': 44452,
#  'throat is so': 67401,
#  'is so sore': 35104,
#  'so sore just': 57729,
#  'sore just have': 58557,
#  'just have to': 36863,
#  'have to whisper': 29390,
#  'ive always been': 36280,
#  'always been very': 2109,
#  'been very nervous': 9804,
#  'very nervous to': 72618,
#  'nervous to do': 45108,
#  'to do something': 68461,
#  'do something like': 16931,
#  'something like that': 58305,
#  'like that as': 39176,
#  'that as feel': 61250,
#  'as feel like': 7087,
#  'feel like am': 20963,
#  'like am not': 38627,
#  'am not really': 2579,
#  'not really that': 45998,
#  'really that talented': 53526,
#  'that talented to': 62226,
#  'talented to enter': 60585,
#  'to enter something': 68529,
#  'enter something into': 18485,
#  'something into an': 58298,
#  'into an official': 34348,
#  'an official contest': 3027,
#  'feel bit pissed': 20238,
#  'bit pissed off': 10582,
#  'pissed off because': 51413,
#  'off because we': 47965,
#  'because we went': 9481,
#  'we went first': 74494,
#  'feel satisfied knowing': 21645,
#  'satisfied knowing the': 54960,
#  'knowing the dirt': 37705,
#  'the dirt and': 63143,
#  'dirt and hair': 16440,
#  'and hair is': 3984,
#  'hair is no': 28269,
#  'is no longer': 34950,
#  'no longer in': 45451,
#  'longer in the': 39988,
#  'in the car': 33511,
#  'the car and': 62897,
#  'car and house': 13039,
#  'really like how': 53453,
#  'like how the': 38848,
#  'how the special': 31407,
#  'the special edition': 64608,
#  'special edition really': 58699,
#  'edition really does': 18006,
#  'really does feel': 53357,
#  'does feel special': 17042,
#  'feel special with': 21903,
#  'special with songs': 58716,
#  'with songs on': 77148,
#  'songs on it': 58524,
#  'would accept your': 77944,
#  'accept your gift': 677,
#  'your gift without': 79102,
#  'gift without feeling': 26777,
#  'without feeling mad': 77392,
#  'feel hesitant to': 20689,
#  'hesitant to do': 30456,
#  'to do it': 68450,
#  'do it since': 16859,
#  'it since don': 35876,
#  'since don have': 56655,
#  'don have any': 17246,
#  'have any experience': 28848,
#  'any experience with': 6146,
#  'experience with programming': 19350,
#  'with programming and': 77099,
#  'programming and all': 52403,
#  'was feeling particularly': 73572,
#  'feeling particularly bitchy': 23316,
#  'particularly bitchy and': 50583,
#  'bitchy and dont': 10647,
#  'and dont think': 3548,
#  'dont think adequately': 17438,
#  'think adequately expressed': 66271,
#  'adequately expressed my': 940,
#  'expressed my appreciation': 19422,
#  'my appreciation for': 43330,
#  'appreciation for that': 6418,
#  'do feel confused': 16790,
#  'im with you': 32698,
#  'with you when': 77340,
#  'you when your': 79020,
#  'when your professor': 75699,
#  'your professor looks': 79143,
#  'professor looks at': 52395,
#  'looks at you': 40105,
#  'at you like': 7981,
#  'you like spitball': 78847,
#  'like spitball when': 39158,
#  'spitball when your': 58819,
#  'when your friend': 75698,
#  'your friend is': 79100,
#  'friend is dying': 25669,
#  'is dying when': 34779,
#  'dying when you': 17803,
#  'when you cry': 75686,
#  'you cry into': 78694,
#  'cry into your': 15244,
#  'into your pillow': 34487,
#  'your pillow at': 79139,
#  'pillow at night': 51377,
#  'at night when': 7816,
#  'night when you': 45385,
#  'when you feel': 75690,
#  'you feel the': 78763,
#  'feel the dangerous': 22108,
#  'the dangerous tickles': 63080,
#  'dangerous tickles of': 15454,
#  'tickles of jealousy': 67514,
#  'of jealousy luring': 46990,
#  'jealousy luring you': 36494,
#  'luring you down': 40482,
#  'you down into': 78716,
#  'down into its': 17564,
#  'into its lair': 34381,
#  'didn feel rushed': 16229,
#  'feel rushed to': 21626,
#  'rushed to finish': 54714,
#  'to finish millions': 68782,
#  'finish millions of': 24522,
#  'millions of things': 42164,
#  ...}

# %%
from sklearn.model_selection import train_test_split as tts
X_train, X_test, y_train, y_test = tts(df.Comment, df.Emotion_label, test_size=0.2, random_state=2023, stratify=df.Emotion_label)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# %%
clf = Pipeline([
    ('count_vectorizer', CountVectorizer(ngram_range = (3, 3))),
    ('rand_forest', RandomForestClassifier())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.24      0.33       400
#            1       0.59      0.23      0.33       400
#            2       0.37      0.83      0.52       388
#
#     accuracy                           0.43      1188
#    macro avg       0.50      0.43      0.39      1188
# weighted avg       0.50      0.43      0.39      1188

# %%
clf = Pipeline([
    ('count_vectorizer', CountVectorizer(ngram_range = (1,2))),
    ('multi_nb', MultinomialNB())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       400
#            1       0.89      0.83      0.86       400
#            2       0.86      0.89      0.87       388
#
#     accuracy                           0.86      1188
#    macro avg       0.86      0.86      0.86      1188
# weighted avg       0.86      0.86      0.86      1188

# %%
clf = Pipeline([
    ('count_vectorizer', CountVectorizer(ngram_range = (1,2))),
    ('rand_forest', RandomForestClassifier())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       400
#            1       0.84      0.96      0.90       400
#            2       0.94      0.85      0.90       388
#
#     accuracy                           0.90      1188
#    macro avg       0.91      0.90      0.90      1188
# weighted avg       0.90      0.90      0.90      1188

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
clf = Pipeline([
    ('count_vectorizer', TfidfVectorizer()),
    ('rand_forest', RandomForestClassifier())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.91       400
#            1       0.87      0.94      0.90       400
#            2       0.92      0.89      0.91       388
#
#     accuracy                           0.90      1188
#    macro avg       0.91      0.90      0.90      1188
# weighted avg       0.91      0.90      0.90      1188

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

def preprocess(text):
    doc = nlp(text)
    
    filtered_tokens = []
    for token in doc:
        if token.is_stop or token.is_punct:
            continue
        filtered_tokens.append(token.lemma_)
        
    return ' '.join(filtered_tokens)

# %%
df['preprocessed_comment'] = df.Comment.apply(preprocess)

# %%
df
# Out:
#                                                 Comment Emotion  \
# 0     i seriously hate one subject to death but now ...    fear
# 1                    im so full of life i feel appalled   anger
# 2     i sit here to write i start to dig out my feel...    fear
# 3     ive been really angry with r and i feel like a...     joy
# 4     i feel suspicious if there is no one outside l...    fear
# ...                                                 ...     ...
# 5932                 i begun to feel distressed for you    fear
# 5933  i left feeling annoyed and angry thinking that...   anger
# 5934  i were to ever get married i d have everything...     joy
# 5935  i feel reluctant in applying there because i w...    fear
# 5936  i just wanted to apologize to you because i fe...   anger
#
#       Emotion_label                               preprocessed_comment
# 0                 2   seriously hate subject death feel reluctant drop
# 1                 0                                  m life feel appal
# 2                 2  sit write start dig feeling think afraid accep...
# 3                 1             ve angry r feel like idiot trust place
# 4                 2        feel suspicious outside like rapture happen
# ...             ...                                                ...
# 5932              2                              begin feel distressed
# 5933              0  leave feel annoyed angry thinking center stupi...
# 5934              1  married d ready offer ve get club perfect good...
# 5935              2  feel reluctant apply want able find company kn...
# 5936              0           want apologize feel like heartless bitch
#
# [5937 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = tts(df.preprocessed_comment, df.Emotion_label, test_size=0.2, random_state=2022, stratify=df.Emotion_label)

# %%
clf = Pipeline([
    ('count_vectorizer', CountVectorizer(ngram_range = (1,2))),
    ('rand_forest', RandomForestClassifier())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       400
#            1       0.93      0.95      0.94       400
#            2       0.95      0.90      0.92       388
#
#     accuracy                           0.93      1188
#    macro avg       0.93      0.93      0.93      1188
# weighted avg       0.93      0.93      0.93      1188

# %%
clf = Pipeline([
    ('count_vectorizer', TfidfVectorizer()),
    ('rand_forest', RandomForestClassifier())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92       400
#            1       0.93      0.94      0.94       400
#            2       0.91      0.93      0.92       388
#
#     accuracy                           0.93      1188
#    macro avg       0.93      0.93      0.93      1188
# weighted avg       0.93      0.93      0.93      1188
